# %% [markdown]
# # API Interface

# %% [markdown]
# ## Importing Libraries
#
# I imported `urllib2` and `pandas` as per most of the assignments so far this semester.  Since we are working with an API and having it return a .json file, I also imported the `json` library.

# %%
import urllib2
import json
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# ## Calling the API
#
# Below is the object `html` that I used to store the requested URL to call the API from the New York Times. For this assignment, I thought it would be interesting to work with the NYT Events API.
#
# In the URL, you can see the `'&11=...'`, which is the parameter entered to find events in a certain location.  The latitude and longitude coordinates are the location of the New York Times building. By default, the radius for events occuring around the specified coordinates is 1 kilometer.  This can be changed, as well as other parameters by entering additional values in the URL.

# %%
html = urllib2.urlopen('http://api.nytimes.com/svc/events/v2/listings.json?&ll=40.756146,-73.99021&api-key=ecd26a19bd89bc2159d2c599b3ebf474:13:73284354')

# %% [markdown]
# Now we can see that the object `html` is returning something.  By default, the New York Times APIs return a .json file, but can return .xml or .sphp files as well.

# %%
html
# Out:
# <addinfourl at 4444300352 whose fp = <socket._fileobject object at 0x108df2d50>>

# %% [markdown]
# ## Opening the .json File
#
# The `data` object stores the opened .json file, by calling `json.load()`.

# %%
data = json.load(html)

# %% [markdown]
# Now we can see what the .json file contains:

# %%
data
# Out:
# {u'copyright': u'Copyright (c) 2015 The New York Times Company.  All Rights Reserved.',
#  u'num_results': 73,
#  u'results': [{u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'The New York Times',
#    u'cross_street': u'between Broadway and Eighth Avenue',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/off-broadway/perfect-crime-128.html',
#    u'event_id': 128,
#    u'event_name': u'\u2018Perfect Crime\u2019',
#    u'event_schedule_id': 336,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.76159',
#    u'geocode_longitude': u'-73.984485',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2014-01-21T10:55:38.2Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'previews_and_openings': False,
#    u'recur_days': [u'mon', u'tue', u'wed', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2010-07-19T04:00:00.199Z',
#    u'state': u'NY',
#    u'street_address': u'210 West 50th Street',
#    u'subcategory': u'Off Broadway',
#    u'telephone': u'800-745-3000',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/7701/The-Perfect-Crime/overview',
#    u'theater_review_url': u'http://www.nytimes.com/2005/10/03/theater/reviews/03perf.html',
#    u'theater_ticket_url': u'http://ticketsus.at/nytimes?CTY=37&DURL=http://www.ticketmaster.com/artist/935439',
#    u'times_pick': False,
#    u'venue_name': u'Snapple Theater Center',
#    u'venue_website': u'ticketmaster.com',
#    u'web_description': u'<p>Did the psychiatrist do it? This small-scale murder mystery has been running in New York since 1987 (1:30).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'The New York Times',
#    u'cross_street': u'between Eighth and Ninth Avenues',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/off-broadway/avenue-q-126.html',
#    u'event_id': 126,
#    u'event_name': u'\u2018Avenue Q\u2019',
#    u'event_schedule_id': 320,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.7629',
#    u'geocode_longitude': u'-73.98751',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2014-01-21T10:55:38.2Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Clinton',
#    u'previews_and_openings': False,
#    u'recur_days': [u'mon', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2009-10-05T04:00:00.277Z',
#    u'state': u'NY',
#    u'street_address': u'340 West 50th Street',
#    u'subcategory': u'Off Broadway',
#    u'telephone': u'212-239-6200',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/24207/Avenue-Q/overview',
#    u'theater_review_url': u'http://www.nytimes.com/2009/10/22/theater/reviews/22avenue.html',
#    u'theater_ticket_url': u'http://www.telecharge.com/go.aspx?MD=1001&PID=7685&AID=AFF000006400&BID=5',
#    u'times_pick': False,
#    u'venue_name': u'New World Stages',
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>A &#8220;Sesame Street&#8221; for confused young adults, with R-rated puppets giving lively life lessons amid the human cast. This 2003 musical has traveled from Off Broadway to a Tony-winning Broadway run and back to an Off Broadway house, with its wit and sex intact (2:15).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'forChildren',
#    u'city': u'New York',
#    u'critic_name': u'Laurel Graeber',
#    u'cross_street': u'between Eighth and Ninth Avenues',
#    u'date_time_description': u'Fridays and Thursdays at 8 p.m.; Saturdays at 2:30 and 8 p.m.; Sundays at 3 and 7 p.m.; Mondays and Wednesdays at 7 p.m. ',
#    u'event_detail_url': u'http://nytimes.com/events/forchildren/iluminate-14110.html',
#    u'event_id': 14110,
#    u'event_name': u'iLuminate',
#    u'event_schedule_id': 16311,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.7629',
#    u'geocode_longitude': u'-73.98751',
#    u'kid_friendly': True,
#    u'last_chance': False,
#    u'last_modified': u'2014-05-08T05:54:38.127Z',
#    u'long_running_show': False,
#    u'neighborhood': u'Clinton',
#    u'postal_code': u'10019',
#    u'previews_and_openings': False,
#    u'price': u'$49.99 and $69.99; $26 for rush and student tickets, available at the box office only',
#    u'recur_days': [u'mon', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2013-07-18T04:00:00.198Z',
#    u'state': u'NY',
#    u'street_address': u'340 West 50th Street',
#    u'telephone': u'212-239-6200',
#    u'times_pick': False,
#    u'venue_detail_url': u'http://nytimes.com/events/venues/new-world-stages-314.html',
#    u'venue_name': u'New World Stages',
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>At this hourlong Off Broadway production, it isn&#8217;t the names that go up in lights. Founded by Miral Kotb, a dancer and software engineer, the troupe&#160; iLuminate uses wireless programs to light up the bodies of its performers, turning them into glowing silhouettes that perform in total darkness. Using music, dance and virtually no dialogue, the company tells the story of Jacob, an artist whose magic paintbrush, which turns his creations into living beings, is stolen for evil ends. The results tend to favor technology over art, but it&#8217;s still fun to watch these young dancers shine.</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'The New York Times',
#    u'cross_street': u'between Broadway and Eigth Avenue',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/chicago-117.html',
#    u'event_id': 117,
#    u'event_name': u'\u2018Chicago\u2019',
#    u'event_schedule_id': 308,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.761067',
#    u'geocode_longitude': u'-73.984884',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2014-11-19T17:41:29.322Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'previews_and_openings': False,
#    u'recur_days': [u'mon', u'tue', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2009-06-18T04:00:00.168Z',
#    u'state': u'NY',
#    u'street_address': u'219 West 49th Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'212-239-6200',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/24024/Chicago/overview',
#    u'theater_review_url': u'http://www.nytimes.com/2003/08/04/theater/theater-review-movie-doll-hits-broadway-without-breaking-a-sweat.html',
#    u'theater_ticket_url': u'http://www.telecharge.com/go.aspx?MD=1001&PID=493&&AID=AFF000006400&BID=5',
#    u'times_pick': False,
#    u'venue_name': u'Ambassador Theater',
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>Jazz Age sex, murder and razzle-dazzle heat up this dance-fueled musical, revived on Broadway in 1996 and continuing since with an eclectic, ever-changing selection of Roxies, Velmas and Billy Flynns (2:25).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'The New York Times',
#    u'cross_street': u'between Seventh and Eighth Avenues',
#    u'date_time_description': u'continuing ',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/wicked-136.html',
#    u'event_id': 136,
#    u'event_name': u'\u2018Wicked\u2019',
#    u'event_schedule_id': 317,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.762436',
#    u'geocode_longitude': u'-73.984834',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-01-07T16:01:41.6Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Midtown',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2003-10-30T05:00:00.302Z',
#    u'state': u'NY',
#    u'street_address': u'222 West 51st Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'800-745-3000',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/4723/Wicked/overview',
#    u'theater_review_url': u'http://www.nytimes.com/2014/08/22/theater/a-decade-later-wicked-continues-to-be-catnip-for-tweens.html',
#    u'theater_ticket_url': u'http://ticketsus.at/nytimes?CTY=37&DURL=http://www.ticketmaster.com/artist/965961',
#    u'times_pick': False,
#    u'venue_name': u'Gershwin Theater',
#    u'venue_website': u'ticketmaster.com',
#    u'web_description': u'<p>One of the most popular Broadway shows since its 2003 opening &#8212; and featuring the song &#8220;Defying Gravity,&#8221; which you&#8217;ve no doubt heard in countless renditions &#8212; this musical revisionist view of Oz, focusing on Glinda the Good Witch and her rival, the Wicked (or is she?) Witch Elphaba, champions the misunderstood young woman in a spectacle directed by Joe Mantello (2:45).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'The New York Times',
#    u'cross_street': u'at Broadway',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/the-lion-king-119.html',
#    u'event_id': 119,
#    u'event_name': u'\u2018The Lion King\u2019',
#    u'event_schedule_id': 313,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.757986',
#    u'geocode_longitude': u'-73.985643',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-01-07T16:01:42.6Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2009-06-18T04:00:00.168Z',
#    u'state': u'NY',
#    u'street_address': u'200 West 45th Street, at Broadway',
#    u'subcategory': u'Broadway',
#    u'telephone': u'800-870-2717',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/24223/The-Lion-King/overview',
#    u'theater_review_url': u'http://www.nytimes.com/1997/11/14/movies/theater-review-cub-comes-of-age-a-twice-told-cosmic-tale.html',
#    u'theater_ticket_url': u'http://ticketsus.at/nytimes?CTY=37&DURL=http://www.ticketmaster.com/artist/1039581',
#    u'times_pick': False,
#    u'venue_name': u'Minskoff Theater',
#    u'venue_website': u'ticketmaster.com',
#    u'web_description': u'<p>The director Julie Taymor&#8217;s puppet- and spectacle-filled take on Disney&#8217;s call of the wild, based on the 1994 animated film and a standard on Broadway since 1997, with a score by Elton John and Tim Rice (2:45).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'The New York Times',
#    u'cross_street': u'between Seventh and Eighth Avenues',
#    u'date_time_description': u'continuing ',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/the-phantom-of-the-opera-114.html',
#    u'event_id': 114,
#    u'event_name': u'\u2018The Phantom of the Opera\u2019',
#    u'event_schedule_id': 316,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.758172',
#    u'geocode_longitude': u'-73.98791',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-01-07T16:01:43.6Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'previews_and_openings': False,
#    u'recur_days': [u'mon', u'tue', u'wed', u'thu', u'fri', u'sat'],
#    u'recurring_start_date': u'2009-06-18T04:00:00.168Z',
#    u'state': u'NY',
#    u'street_address': u'247 West 44th Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'212-239-6200',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/24191/The-Phantom-of-the-Opera/overview',
#    u'theater_review_url': u'http://www.nytimes.com/2014/08/18/theater/the-phantom-of-the-opera-retains-its-luster.html',
#    u'theater_ticket_url': u'http://www.telecharge.com/go.aspx?MD=1001&PID=263&AID=AFF000006400&BID=5',
#    u'times_pick': False,
#    u'venue_name': u'Majestic Theater',
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>&#8220;The Music of the Night&#8221; and the fantastical staging &#8212; and that chandelier! &#8212; remain since the 1988 opening of this Andrew Lloyd Webber musical. The show, as Frank Rich described it in 1988, is a highly romanticized &#8220;beast-meets-beauty, loses-beauty story&#8221; set in Paris (2:30).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'The New York Times',
#    u'cross_street': u'between Seventh and Eighth Avenues',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/jersey-boys-118.html',
#    u'event_id': 118,
#    u'event_name': u'\u2018Jersey Boys\u2019',
#    u'event_schedule_id': 312,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.763252',
#    u'geocode_longitude': u'-73.984389',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-01-07T16:01:43.6Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Midtown',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2009-06-18T04:00:00.168Z',
#    u'state': u'NY',
#    u'street_address': u'245 West 52nd Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'212-239-6200',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/24193/Jersey-Boys/overview',
#    u'theater_review_url': u'http://www.nytimes.com/2005/11/07/theater/reviews/07jers.html',
#    u'theater_ticket_url': u'http://www.telecharge.com/go.aspx?MD=1001&PID=5171&AID=AFF000006400&BID=5',
#    u'times_pick': False,
#    u'venue_name': u'August Wilson Theater',
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>This biomusical that walks like a man tells the story of Frankie Valli and the Four Seasons. The Tony-winning show has been a fixture on Broadway since 2005 (2:30).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Ben Brantley',
#    u'cross_street': u'between Seventh and Eighth Avenues',
#    u'date_time_description': u'continuing ',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/matilda-the-musical-10815.html',
#    u'event_id': 10815,
#    u'event_name': u'\u2018Matilda the Musical\u2019 ',
#    u'event_schedule_id': 12766,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.757901',
#    u'geocode_longitude': u'-73.98717',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-01-07T16:01:43.6Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2013-03-04T05:00:00.62Z',
#    u'state': u'NY',
#    u'street_address': u'225 West 44th Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'212-239-6200',
#    u'times_pick': False,
#    u'venue_detail_url': u'http://nytimes.com/events/venues/shubert-theater-376.html',
#    u'venue_name': u'Shubert Theater',
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>The most satisfying and subversive musical ever to come out of Britain. Directed by Matthew Warchus, with a book by Dennis Kelly and addictive songs by Tim Minchin, this adaptation of Roald Dahl&#8217;s novel is an exhilarating tale of empowerment, told from the perspective of that most powerless group, little children (2:35).&#160;</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Ben Brantley',
#    u'cross_street': u'between Seventh and Eighth Avenues',
#    u'date_time_description': u'continuing ',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/the-book-of-mormon-148.html',
#    u'event_id': 148,
#    u'event_name': u'\u2018The Book of Mormon\u2019',
#    u'event_schedule_id': 354,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.761249',
#    u'geocode_longitude': u'-73.985628',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-01-07T16:01:43.6Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'postal_code': u'10019',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2011-02-24T05:00:00.54Z',
#    u'state': u'NY',
#    u'street_address': u'230 West 49th Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'800-432-7250',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/25456/The-Book-of-Mormon/overview',
#    u'theater_review_url': u'http://www.nytimes.com/2014/08/21/theater/the-book-of-mormon-on-broadway-retains-its-charms.html',
#    u'theater_ticket_url': u'http://www.telecharge.com/go.aspx?MD=1001&PID=8351&AID=AFF000006400&BID=5',
#    u'times_pick': False,
#    u'venue_name': u"Eugene O'Neill Theater",
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>This delightful collaboration between the creators of &#8220;South Park&#8221; (Trey Parker and Matt Stone) and the composer of &#8220;Avenue Q&#8221; (Robert Lopez) is blasphemous, scurrilous and as pure-hearted as a Rodgers and Hammerstein show. No musical has so successfully had it both ways since &#8220;The Producers.&#8221; Casey Nicholaw is the witty co-director (with Mr. Parker) and choreographer&#160;(2:15).&#160;</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Ben Brantley',
#    u'cross_street': u'between Eighth and Ninth Avenues',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/kinky-boots-10812.html',
#    u'event_id': 10812,
#    u'event_name': u'\u2018Kinky Boots\u2019',
#    u'event_schedule_id': 12763,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.759258',
#    u'geocode_longitude': u'-73.989205',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-02-11T12:33:43.41Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Clinton',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2013-03-03T05:00:00.61Z',
#    u'state': u'NY',
#    u'street_address': u'302 West 45th Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'212-239-6200',
#    u'times_pick': False,
#    u'venue_detail_url': u'http://nytimes.com/events/venues/al-hirschfeld-theater-19.html',
#    u'venue_name': u'Al Hirschfeld Theater',
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>Cyndi Lauper has created a love-and-heat-seeking score that performs like a pop star on Ecstasy. This Harvey Fierstein-scripted tale of lost souls in the shoe business, in which a young factory owner teams up with a drag queen,&#160; sometimes turns into a sermon. But it&#8217;s hard to resist the audience-hugging charisma of the songs (2:20).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Charles Isherwood',
#    u'cross_street': u'near Eighth Avenue',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/extravaganzas/queen-of-the-night-16414.html',
#    u'event_id': 16414,
#    u'event_name': u'\u2018Queen of the Night\u2019 ',
#    u'event_schedule_id': 19070,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.759642',
#    u'geocode_longitude': u'-73.986987',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-02-24T10:31:02.54Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'postal_code': u'10036',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2013-12-31T05:00:00.364Z',
#    u'state': u'NY',
#    u'street_address': u'235 West 46th Street',
#    u'subcategory': u'Extravaganzas',
#    u'telephone': u'866-811-4111',
#    u'times_pick': False,
#    u'venue_name': u'Diamond Horseshoe at the Paramount Hotel',
#    u'venue_website': u'queenofthenightnyc.com',
#    u'web_description': u'<p>The latest and most lavish of this city&#8217;s immersive theater experiments includes cocktails, a meal and a circus-style floor show, in addition to any number of possible intimate, eroticism-tinged (but PG-13) encounters with the comely young cast members. The show is not for those prone to social anxiety, but it&#8217;s full of gaudy spectacle, with a fin-de-Bloomberg-era vibe (2:45).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Ben Brantley',
#    u'cross_street': u'between Avenue of the Americas and Seventh Avenue',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/beautiful-the-carole-king-musical-15713.html',
#    u'event_id': 15713,
#    u'event_name': u'\u2018Beautiful: The Carole King Musical\u2019 ',
#    u'event_schedule_id': 18256,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.756211',
#    u'geocode_longitude': u'-73.985316',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-03-05T17:15:17.63Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'postal_code': u'10036',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2013-11-21T05:00:00.324Z',
#    u'state': u'NY',
#    u'street_address': u'124 West 43rd Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'212-239-6200',
#    u'times_pick': False,
#    u'venue_detail_url': u'http://nytimes.com/events/venues/stephen-sondheim-theater-396.html',
#    u'venue_name': u'Stephen Sondheim Theater',
#    u'venue_website': u'telecharge.com',
#    u'web_description': u'<p>This friendly, formulaic jukebox show about the New York-born singer-songwriter might as well be called &#8220;Brooklyn Girl,&#8221; so closely does it adhere to the template of the megahit &#8220;Jersey Boys&#8221; (about the Four Seasons)&#160; (2:25).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'cross_street': u'between Seventh and Eighth Avenues',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/aladdin-17385.html',
#    u'event_id': 17385,
#    u'event_name': u'\u2018Aladdin\u2019 ',
#    u'event_schedule_id': 20100,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.756246',
#    u'geocode_longitude': u'-73.987985',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-03-25T12:24:59.83Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2014-02-26T05:00:00.56Z',
#    u'state': u'NY',
#    u'street_address': u'214 West 42nd Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'866-870-2717',
#    u'times_pick': False,
#    u'venue_detail_url': u'http://nytimes.com/events/venues/new-amsterdam-theater-308.html',
#    u'venue_name': u'New Amsterdam Theater',
#    u'venue_website': u'aladdinthemusical.com',
#    u'web_description': u'<p>Casey Nicholaw (&#8220;The Book of Mormon&#8221;) directs and choreographs (and choreographs, and choreographs) the latest Disney musical, adapted from the 1992 animated movie. While the familiar formulas are not entirely abandoned, Mr. Nicholaw and the book writer, Chad Beguelin, stuff so much splashy, shticky business into this show that the more syrupy bits hardly register. James Monroe Iglehart stands out as the showboating, scene-stealing genie (2:20).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Ben Brantley',
#    u'cross_street': u'between Seventh and Eighth Avenues',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/something-rotten-24662.html',
#    u'event_id': 24662,
#    u'event_name': u'\u2018Something Rotten!\u2019',
#    u'event_schedule_id': 27949,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.758116',
#    u'geocode_longitude': u'-73.988093',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-04-29T16:51:20.118Z',
#    u'long_running_show': False,
#    u'neighborhood': u'Times Square Theatre District',
#    u'postal_code': u'10036',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2015-03-23T04:00:00.81Z',
#    u'state': u'NY',
#    u'street_address': u'246 West 44th Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'212-239-6200',
#    u'times_pick': False,
#    u'venue_detail_url': u'http://nytimes.com/events/venues/st-james-theater-392.html',
#    u'venue_name': u'St. James Theater',
#    u'venue_website': u'rottenbroadway.com',
#    u'web_description': u'<p>This rambunctious show, which weds the Elizabethan theater and the brassy Broadway musical, dances dangerously on the line between tireless and tedious. But the large cast, which includes Brian D&#8217;Arcy James and Christian Borle, remains as wired as Adderall-popping sophomores during exam week. Casey Nicholaw directed this exhausting frolic from Wayne and Karey Kirkpatrick, and John O&#8217;Farrell (2:20).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'The New York Times',
#    u'cross_street': u'between Broadway and Eighth Avenue',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/off-broadway/the-fantasticks-124.html',
#    u'event_id': 124,
#    u'event_name': u'\u2018The Fantasticks\u2019',
#    u'event_schedule_id': 309,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.76159',
#    u'geocode_longitude': u'-73.984485',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-04-29T16:51:21.118Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Times Square Theatre District',
#    u'previews_and_openings': False,
#    u'recur_days': [u'mon', u'tue', u'wed', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2009-06-18T04:00:00.168Z',
#    u'state': u'NY',
#    u'street_address': u'210 West 50th Street',
#    u'subcategory': u'Off Broadway',
#    u'telephone': u'800-745-3000',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/22379/The-Fantasticks/overview',
#    u'theater_ticket_url': u'http://ticketsus.at/nytimes?CTY=37&DURL=http://www.ticketmaster.com/artist/891314',
#    u'times_pick': False,
#    u'venue_name': u'Snapple Theater Center',
#    u'venue_website': u'ticketmaster.com',
#    u'web_description': u'<p>Try to remember, if you can, this show&#8217;s first Off Broadway performance, back in 1960. No? If not &#8212; and whether you have or haven&#8217;t seen the many incarnations of this classic around the nation, from high schools and colleges, to community theaters and regional productions &#8212; there&#8217;s still an Off Broadway cast regularly offering &#8220;Try to Remember&#8221; and the many other songs from this canonical American musical, in which boy meets girl, forever (2:05).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Charles Isherwood',
#    u'cross_street': u'at West 47th Street',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/an-american-in-paris-24541.html',
#    u'event_id': 24541,
#    u'event_name': u'\u2018An American in Paris\u2019',
#    u'event_schedule_id': 27789,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.758977',
#    u'geocode_longitude': u'-73.985211',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-05-06T12:13:41.125Z',
#    u'long_running_show': False,
#    u'neighborhood': u'Times Square Theatre District',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2015-03-13T04:00:00.71Z',
#    u'state': u'NY',
#    u'street_address': u'1564 Broadway',
#    u'subcategory': u'Broadway',
#    u'telephone': u'877-250-2929',
#    u'times_pick': True,
#    u'venue_detail_url': u'http://nytimes.com/events/venues/palace-theater-332.html',
#    u'venue_name': u'Palace Theater',
#    u'venue_website': u'ticketmaster.com',
#    u'web_description': u'<p>The ballet luminary Christopher Wheeldon makes a triumphant debut as a Broadway director with this rhapsodic stage adaptation of a classic musical with a heavenly Gershwin score. The ballet dancers Robert Fairchild and Leanne Cope, as the semi-star-crossed lovers, are radiant, and Max von Essen sings like a dream as an heir who aspires to a nightclub career. Pure joy (2:30).&#160;</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York ',
#    u'critic_name': u'Anita Gates',
#    u'cross_street': u'between Eighth and Ninth Avenues',
#    u'date_time_description': u'Saturdays and Sundays',
#    u'event_detail_url': u'http://nytimes.com/events/theater/off-broadway/sistas-the-musical-2166.html',
#    u'event_id': 2166,
#    u'event_name': u'\u2018Sistas: The Musical\u2019',
#    u'event_schedule_id': 2946,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.759951531678865',
#    u'geocode_longitude': u'-73.98871406878663',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-07-15T05:45:32.195Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Clinton',
#    u'postal_code': u'10036',
#    u'previews_and_openings': False,
#    u'recur_days': [u'sat', u'sun'],
#    u'recurring_start_date': u'2011-10-21T04:00:00.293Z',
#    u'state': u'NY',
#    u'street_address': u'308 West 46th Street',
#    u'subcategory': u'Off Broadway',
#    u'telephone': u'212-239-6200',
#    u'theater_overview_url': u'http://www.nytimes.com/theater/show/30093/Sistas-The-Musical/overview',
#    u'theater_review_url': u'http://www.nytimes.com/2011/10/29/theater/reviews/sistas-the-musical-review.html',
#    u'theater_ticket_url': u'http://www.telecharge.com/go.aspx?MD=1001&PID=8632&AID=AFF000006400&BID=5',
#    u'times_pick': False,
#    u'venue_name': u'St. Luke\u2019s Theater',
#    u'venue_website': u'sistasthemusical.com',
#    u'web_description': u'<p>The script is obvious, covering virtually every issue that might touch the lives of black women, but Dorothy Marcic&#8217;s good-natured, low-budget musical is all about the songs. From &#8220;Ain&#8217;t Nobody&#8217;s Business if I Do&#8221; to &#8220;Single Ladies,&#8221; you could do a lot worse (1:30).&#160;</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Ben Brantley',
#    u'cross_street': u'between Seventh and Eighth Avenues',
#    u'date_time_description': u'ongoing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/broadway/hamilton-26768.html',
#    u'event_id': 26768,
#    u'event_name': u'\u2018Hamilton\u2019 ',
#    u'event_schedule_id': 29959,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.759083',
#    u'geocode_longitude': u'-73.986632',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-08-12T10:05:11.223Z',
#    u'long_running_show': False,
#    u'neighborhood': u'Times Square Theatre District',
#    u'postal_code': u'10036',
#    u'previews_and_openings': False,
#    u'recur_days': [u'tue', u'wed', u'thu', u'fri', u'sat', u'sun'],
#    u'recurring_start_date': u'2015-07-13T04:00:00.193Z',
#    u'state': u'NY',
#    u'street_address': u'226 West 46th Street',
#    u'subcategory': u'Broadway',
#    u'telephone': u'877-250-2929',
#    u'times_pick': True,
#    u'venue_detail_url': u'http://nytimes.com/events/venues/richard-rodgers-theater-355.html',
#    u'venue_name': u'Richard Rodgers Theater',
#    u'venue_website': u'hamiltonbroadway.com',
#    u'web_description': u'<p>Yes, it really is that good. Lin-Manuel Miranda&#8217;s rap-driven portrait of the rise and fall of Alexander Hamilton, directed by Thomas Kail, makes us feel the unstoppable, urgent rhythm of a nation being born. A show that changes the language of the American musical, while offering resounding evidence that this beleaguered genre is not only surviving but thriving (2:45).</p>'},
#   {u'borough': u'Manhattan',
#    u'category': u'Theater',
#    u'city': u'New York',
#    u'critic_name': u'Anita Gates',
#    u'cross_street': u'at 47th Street',
#    u'date_time_description': u'continuing',
#    u'event_detail_url': u'http://nytimes.com/events/theater/off-broadway/sex-tips-for-straight-women-from-a-gay-man-17378.html',
#    u'event_id': 17378,
#    u'event_name': u'\u2018Sex Tips for Straight Women From a Gay Man\u2019',
#    u'event_schedule_id': 19926,
#    u'festival': False,
#    u'free': False,
#    u'geocode_latitude': u'40.7607386',
#    u'geocode_longitude': u'-73.9874926',
#    u'kid_friendly': False,
#    u'last_chance': False,
#    u'last_modified': u'2015-08-19T16:43:56.23Z',
#    u'long_running_show': True,
#    u'neighborhood': u'Clinton',
#    u'postal_code': u'10036',
#    u'previews_and_openings': False,
#    u'recur_days': [u'fri', u'sat'],
#    u'recurring_start_date': u'2014-02-07T05:00:00.37Z',
#    u'state': u'NY',
#    u'street_address': u'777 Eighth Avenue',
#    u'subcategory': u'Off Broadway',
#    u'telephone': u'888-841-4111',
#    u'times_pick': False,
#    u'venue_name': u'777 Theater',
#    u'venue_website': u'sextipsplay.com',
#    u'web_description': u'<p>Matt Murphy&#8217;s one-act is a blend of a bachelorette party at Chippendales and the embarrassing midnight show at some tourist trap in Pigalle. Talented cast, but it&#8217;s no &#8220;Queer Eye&#8221; (1:20).</p>'}],
#  u'status': u'OK'}

# %% [markdown]
# ### Parsing the .json File
#
# I just wanted create a quick summary of the information contained in the .json file returned from the API.  Below is the code I used to parse through the file, grabbing the event name, borough name, address, and venue name where the event was taking place.

# %%
event_name = []
borough = []
address = []
venue = []
for value in data['results']:
    event_name.append(value['event_name'][1:])
    borough.append(value['borough'])
    address.append(value['street_address'])
    venue.append(value['venue_name'])

# %% [markdown]
# Here is a sample of what one of the lists looks like now:

# %%
event_name
# Out:
# [u'Perfect Crime\u2019',
#  u'Avenue Q\u2019',
#  u'Luminate',
#  u'Chicago\u2019',
#  u'Wicked\u2019',
#  u'The Lion King\u2019',
#  u'The Phantom of the Opera\u2019',
#  u'Jersey Boys\u2019',
#  u'Matilda the Musical\u2019 ',
#  u'The Book of Mormon\u2019',
#  u'Kinky Boots\u2019',
#  u'Queen of the Night\u2019 ',
#  u'Beautiful: The Carole King Musical\u2019 ',
#  u'Aladdin\u2019 ',
#  u'Something Rotten!\u2019',
#  u'The Fantasticks\u2019',
#  u'An American in Paris\u2019',
#  u'Sistas: The Musical\u2019',
#  u'Hamilton\u2019 ',
#  u'Sex Tips for Straight Women From a Gay Man\u2019']

# %% [markdown]
# Just to make sure that all of the lists were the same length, and that no weird headers or anything else were picked up:

# %%
len(event_name)
# Out:
# 20

# %% [markdown]
# ## Creating the DataFrame
#
# As before, I used the individual lists as columns, and zipped them together as one object.

# %%
events_table = zip(event_name, venue, address, borough)
events_table[0:3]
# Out:
# [(u'Perfect Crime\u2019',
#   u'Snapple Theater Center',
#   u'210 West 50th Street',
#   u'Manhattan'),
#  (u'Avenue Q\u2019',
#   u'New World Stages',
#   u'340 West 50th Street',
#   u'Manhattan'),
#  (u'Luminate', u'New World Stages', u'340 West 50th Street', u'Manhattan')]

# %% [markdown]
# Now to make the DataFrame by passing the `events_table` object into the DataFrame() function, and naming the columns:

# %%
df = DataFrame(data = events_table, columns = ['Event Name', 'Venue', 'Address', 'Borough'])
df
# Out:
#                                      Event Name  \
# 0                                Perfect Crime’
# 1                                     Avenue Q’
# 2                                      Luminate
# 3                                      Chicago’
# 4                                       Wicked’
# 5                                The Lion King’
# 6                     The Phantom of the Opera’
# 7                                  Jersey Boys’
# 8                         Matilda the Musical’
# 9                           The Book of Mormon’
# 10                                 Kinky Boots’
# 11                         Queen of the Night’
# 12         Beautiful: The Carole King Musical’
# 13                                    Aladdin’
# 14                           Something Rotten!’
# 15                             The Fantasticks’
# 16                        An American in Paris’
# 17                         Sistas: The Musical’
# 18                                   Hamilton’
# 19  Sex Tips for Straight Women From a Gay Man’
#
#                                        Venue  \
# 0                     Snapple Theater Center
# 1                           New World Stages
# 2                           New World Stages
# 3                         Ambassador Theater
# 4                           Gershwin Theater
# 5                           Minskoff Theater
# 6                           Majestic Theater
# 7                      August Wilson Theater
# 8                            Shubert Theater
# 9                     Eugene O'Neill Theater
# 10                     Al Hirschfeld Theater
# 11  Diamond Horseshoe at the Paramount Hotel
# 12                  Stephen Sondheim Theater
# 13                     New Amsterdam Theater
# 14                         St. James Theater
# 15                    Snapple Theater Center
# 16                            Palace Theater
# 17                        St. Luke’s Theater
# 18                   Richard Rodgers Theater
# 19                               777 Theater
#
#                               Address    Borough
# 0                210 West 50th Street  Manhattan
# 1                340 West 50th Street  Manhattan
# 2                340 West 50th Street  Manhattan
# 3                219 West 49th Street  Manhattan
# 4                222 West 51st Street  Manhattan
# 5   200 West 45th Street, at Broadway  Manhattan
# 6                247 West 44th Street  Manhattan
# 7                245 West 52nd Street  Manhattan
# 8                225 West 44th Street  Manhattan
# 9                230 West 49th Street  Manhattan
# 10               302 West 45th Street  Manhattan
# 11               235 West 46th Street  Manhattan
# 12               124 West 43rd Street  Manhattan
# 13               214 West 42nd Street  Manhattan
# 14               246 West 44th Street  Manhattan
# 15               210 West 50th Street  Manhattan
# 16                      1564 Broadway  Manhattan
# 17               308 West 46th Street  Manhattan
# 18               226 West 46th Street  Manhattan
# 19                  777 Eighth Avenue  Manhattan
